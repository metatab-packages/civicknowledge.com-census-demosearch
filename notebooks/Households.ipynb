# %%
import seaborn as sns
import metapack as mp
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display 
from tqdm.notebook import tqdm

from pathlib import Path

from demosearch import FileCache

# %matplotlib inline
sns.set_context('notebook')
mp.jupyter.init()


# %run ./lib.py

# %%
#pkg = mp.jupyter.open_package()
pkg = mp.jupyter.open_source_package()
pkg
# Out:
# # Demosearch Census Extract
# `civicknowledge.com-census-demosearch-3.1.1` Last Update: 2021-05-27T22:33:29
#
# _Extract of select census variables for demographic radius searches_
#
#
# ## Building the package
#
# Because the package can spend a long time downloading census data, a Jupyter notebook
# will time out. So, to build this package:
#
# 1. Run `invoke build` to build CSV files in the data directory. Use `--force` to overwrite existing files.
# 2. Run `mp build` to build the package
#
#
#
#
# ## Contacts
#
# * **Wrangler** [Eric Busboom](mailto:eric@civicknowledge.com), [Civic Knowledge](http://civicknowledge.com)
#
# ## Resources
#
# * ** [tracts](notebooks/Tracts.ipynb#tracts)**. US Census tracts
# * ** [population](notebooks/Population.ipynb#population)**. US Census population estimates, for tracts
# * ** [households](notebooks/Households.ipynb#households)**. US Census, households, estimates, for tracts
#
# ## References
# ...

# %%
# TODO. Add , B17001

B26103 = pkg.reference('B26103').dataframe()
B26103.titles.head().T.head(40)
# Out:
# geoid                                                                      14000US01001020100  \
# STUSAB                                                                                     AL
# COUNTY                                                                                    001
# NAME                                                Census Tract 201, Autauga County, Alabama
# B26103_001  Total Population  - Total
# B26103_001_m90
# B26103_002 Total Population  - Total  - Group q...
# B26103_002_m90
# B26103_003 Total Population  - Total  - Group q...
# B26103_003_m90
# B26103_004 Total Population  - Total  - Group q...
# B26103_004_m90
# B26103_005 Total Population  - Total  - Group q...
# B26103_005_m90
# B26103_006 Total Population  - Total  - Group q...
# B26103_006_m90
# B26103_007 Total Population  - Total  - Group q...
# B26103_007_m90
# B26103_008 Total Population  - Total  - Househo...
# B26103_008_m90
#
# ...

# %%
# Fetch all of the frames. Cache the dict of frames. By loading it first
# we can add to it if the set of census tables changes. 
     
t = get_group(pkg, 'households')  

households = conform_schema(t, pkg, 'households')
households.head().T
# Out:
#   0%|          | 0/16 [00:00<?, ?it/s]
#                                          0                   1  \
# geoid                   14000US01055010700  14000US01055001300
# tract_id                                 0                   1
# households                            1363                1030
# households_unmaried                     50                  96
# households_cohabiting                 1313                 934
# housing_occupied                      1376                1092
# housing_owned                         1204                 438
# housing_owned_college                  176                  36
# housing_rented                         172                 654
# housing_rented_college                  27                  28
# agg_hh_income                     79543200            35495200
#
#                                          2                   3  \
# geoid                   14000US01055000900  14000US01055001700
# ...
